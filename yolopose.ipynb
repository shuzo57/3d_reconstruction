# %%
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO

# %%
model = YOLO('yolov8s-pose.pt')
# Out:
# ...
# 100%|██████████| 22.4M/22.4M [00:07<00:00, 3.28MB/s]

# %%
img_path = './data/img/red_0712_0016/red_0712_0016_1.jpg'

img = cv2.imread(img_path)
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

fig, ax = plt.subplots(figsize=(7, 7))
ax.imshow(rgb_img)
ax.axis('off')
plt.show()

# %%
resutls = model(img, verbose=False)

# %%
plotted_img = resutls[0].plot()
plotted_img = cv2.cvtColor(plotted_img, cv2.COLOR_BGR2RGB)

fig, ax = plt.subplots(figsize=(7, 7))
ax.imshow(plotted_img)
ax.axis('off')
plt.show()

# %%
resutls[0].boxes.conf
# Out:
# tensor([0.8869])

# %%
resutls[0].boxes.data
# Out:
# tensor([[4.8200e+02, 8.6500e+02, 6.7000e+02, 1.3070e+03, 8.8694e-01, 0.0000e+00]])

# %%
resutls[0].keypoints.conf
# Out:
# tensor([[0.9676, 0.9384, 0.9060, 0.7393, 0.5611, 0.9946, 0.9891, 0.9827, 0.9512, 0.9716, 0.9428, 0.9970, 0.9957, 0.9948, 0.9923, 0.9814, 0.9756]])

# %%
resutls[0].keypoints.data
# Out:
# tensor([[[5.7643e+02, 9.2129e+02, 9.6755e-01],
#          [5.8368e+02, 9.1189e+02, 9.3837e-01],
#          [5.6823e+02, 9.1253e+02, 9.0599e-01],
#          [5.9832e+02, 9.0346e+02, 7.3933e-01],
#          [5.5701e+02, 9.0536e+02, 5.6112e-01],
#          [6.1604e+02, 9.3644e+02, 9.9465e-01],
#          [5.5109e+02, 9.3761e+02, 9.8912e-01],
#          [6.1949e+02, 1.0148e+03, 9.8272e-01],
#          [5.6218e+02, 1.0163e+03, 9.5123e-01],
#          [5.9934e+02, 1.0809e+03, 9.7162e-01],
#          [5.8911e+02, 1.0835e+03, 9.4276e-01],
#          [6.1147e+02, 1.0513e+03, 9.9703e-01],
#          [5.6069e+02, 1.0523e+03, 9.9566e-01],
#          [6.2940e+02, 1.1633e+03, 9.9475e-01],
#          [5.3431e+02, 1.1637e+03, 9.9232e-01],
#          [6.4771e+02, 1.2684e+03, 9.8136e-01],
#          [5.1185e+02, 1.2673e+03, 9.7555e-01]]])
